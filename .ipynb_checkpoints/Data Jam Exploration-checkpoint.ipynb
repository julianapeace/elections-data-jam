# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
#read in the data as pandas dataframes
county_facts = pd.read_csv("../data-jam-august-2016-master/csv/county_facts.csv")
primary_results = pd.read_csv("../data-jam-august-2016-master/csv/primary_results.csv")

# %%
candidates = list(primary_results.candidate.unique())
candidateDFs = {}
for politician in candidates:
    tempKey = politician.strip().lower().replace(' ', '_')
    tempResult = primary_results.iloc[:,3:][primary_results.iloc[:,3:].candidate==politician]
    candidateDFs[tempKey]= tempResult

# %%
complete_frame = county_facts

# %%
for politician in candidateDFs:
    print(politician)
    print(len(complete_frame))
    tempDF = candidateDFs[politician].iloc[:,(0,3)]
    colnames = ['fips1']
    colnames.append(politician)
    tempDF.columns = colnames
    fips_series = tempDF.loc[:,'fips1'].fillna(0).astype('int').to_frame()
    fips_series.columns=['fips']
    tempDF = tempDF.join(fips_series).iloc[:,1:]
    complete_frame1 = pd.merge(complete_frame, tempDF, on=['fips'], how='left')
    complete_frame = complete_frame1
# Out:
# mike_huckabee
# 3195
# ben_carson
# 3195
# john_kasich
# 3204
# donald_trump
# 3294
# hillary_clinton
# 4194
# rick_santorum
# 13194
# uncommitted
# 13194
# no_preference
# 13194
# ted_cruz
# 13194
# jeb_bush
# 103194
# carly_fiorina
# 1003194
# chris_christie
# 10003194
# martin_o'malley
# 100003194

# %%
for politician in candidateDFs:
    print(politician)
# Out:
# mike_huckabee
# ben_carson
# john_kasich
# donald_trump
# hillary_clinton
# rick_santorum
# uncommitted
# no_preference
# ted_cruz
# jeb_bush
# carly_fiorina
# chris_christie
# martin_o'malley
# marco_rubio
# rand_paul
# bernie_sanders

# %%
# %%time
complete_frame = county_facts
temp_frame = candidateDFs['mike_huckabee']
tempDF = temp_frame.iloc[:,(0,3)]
colnames = ['fips1']
colnames.append('mike_huckabee')
tempDF.columns = colnames
fips_series = tempDF.loc[:,'fips1'].fillna(0).astype('int').to_frame()
fips_series.columns=['fips']
tempDF = tempDF.join(fips_series).iloc[:,1:]
complete_frame = pd.merge(complete_frame, tempDF, on=['fips'], how='left')
# Out:
# CPU times: user 9.28 ms, sys: 2.48 ms, total: 11.8 ms
# Wall time: 10.3 ms

# %%
len(candidateDFs.keys())
# Out:
# 16

# %%
primary_results[primary_results.party=="Democrat"]
# Out:
#          state state_abbreviation       county     fips     party  \
# 0      Alabama                 AL      Autauga   1001.0  Democrat
# 1      Alabama                 AL      Autauga   1001.0  Democrat
# 2      Alabama                 AL      Baldwin   1003.0  Democrat
# 3      Alabama                 AL      Baldwin   1003.0  Democrat
# 4      Alabama                 AL      Barbour   1005.0  Democrat
# 5      Alabama                 AL      Barbour   1005.0  Democrat
# 6      Alabama                 AL         Bibb   1007.0  Democrat
# 7      Alabama                 AL         Bibb   1007.0  Democrat
# 8      Alabama                 AL       Blount   1009.0  Democrat
# 9      Alabama                 AL       Blount   1009.0  Democrat
# 10     Alabama                 AL      Bullock   1011.0  Democrat
# 11     Alabama                 AL      Bullock   1011.0  Democrat
# 12     Alabama                 AL       Butler   1013.0  Democrat
# ...
